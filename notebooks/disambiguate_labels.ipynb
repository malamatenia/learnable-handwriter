# %%
import json
import csv
from os.path import join, dirname
import unicodedata

def load_disambiguation_mapping(mapping_path):
    with open(mapping_path, 'r') as file:
        reader = csv.DictReader(file)
        disambiguation_mapping = {row['char']: row['replacement'] for row in reader}
    return disambiguation_mapping

def disambiguate_label(label, disambiguation_mapping):
    print('Before:', label)
    result = ''.join([disambiguation_mapping.get(c, c) for c in unicodedata.normalize('NFC', label)])
    print('After: ', result)
    return result

def disambiguate_line(v, disambiguation_mapping):
    v['label'] = disambiguate_label(v['label'], disambiguation_mapping)
    return v

def extract_post_init(annotation, disambiguation_mapping):
    annotation = {k: disambiguate_line(v, disambiguation_mapping) for k, v in annotation.items()}
    data = [(k, split_combining_(v), v['split']) for k, v in annotation.items()]
    return data

def split_combining_(v):
    label = process_transcription(v['label'])
    return [c for c in unicodedata.normalize('NFC', label)]

def process_transcription(raw_transcription):
    transcription = raw_transcription.replace(space, '')
    if sep != '':
        transcription = transcription.split(sep)
    return transcription

# %%
# Load your annotation data
annotation_path = '/home/vlachoum/PROJECT/learnable-scriber/datasets/textualis_formata/annotation.json'
with open(annotation_path) as f:
    annotation_data = json.load(f)

# Load your disambiguation mapping
mapping_path = '/home/vlachoum/PROJECT/learnable-scriber/learnable_typewriter/data/disambiguation_table.csv'
disambiguation_mapping = load_disambiguation_mapping(mapping_path)

space = ' '  # or whatever your actual definition is
sep = ''  # or whatever your actual definition is

# Extract and disambiguate labels
extracted_data = extract_post_init(annotation_data, disambiguation_mapping)
# Out:
# Before: au sarrazins pour ce quen sa terre fu la ba
# After:  au sarrazins pour ce quen sa terre fu la ba
# Before: taille . ⁊ quil deuoit avoir la premiere poĩ
# After:  taille . ⁊ quil deuoit avoir la premiere poĩ
# Before: te . li quens de triple point seur les sarrazĩs
# After:  te . li quens de triple point seur les sarrazĩs
# Before: et si point en un pendant contreual . li sarra
# After:  et si point en un pendant contreual . li sarra
# Before: zin tantost cõme il fu outre se reclostrent et
# After:  zin tantost cõme il fu outre se reclostrent et
# Before: corurent sus le roi qui demorez estoit si le pri
# After:  corurent sus le roi qui demorez estoit si le pri
# Before: strent ⁊ touz ceus qui auec lui estoient fors
# After:  strent ⁊ touz ceus qui auec lui estoient fors
# Before: seulement ceus qui larrere garde fesoient
# After:  seulement ceus qui larrere garde fesoient
# Before: qui sen eschaperent. quant li quens de tͥple
# After:  qui sen eschaperent. quant li quens de tͥple
# Before: ot point ⁊ il uit que li rois fu pris lui ⁊ sa
# After:  ot point ⁊ il uit que li rois fu pris lui ⁊ sa
# Before: gent . sen foi ⁊ sen ala a sur : ⁊ si estoit taba
# After:  gent . sen foi ⁊ sen ala a sur : ⁊ si estoit taba
# Before: rie a .ij. milles dilec Mes il ni osa aler por
# After:  rie a .ij. milles dilec Mes il ni osa aler por
# Before: ce que il sauoit bien que se il aloit a taba
# After:  ce que il sauoit bien que se il aloit a taba
# Before: rie quil seroit pris quil nem porroit eschaꝑ
# After:  rie quil seroit pris quil nem porroit eschaꝑ
# Before: li filz du prince dantioche. ⁊ li ch̃r quil auo
# After:  li filz du prince dantioche. ⁊ li ch̃r quil auo
# Before: it auec lui amenez estoient auec lui. bali
# After:  it auec lui amenez estoient auec lui. bali
# Before: ens dibelin qui en larriere garde estoit escha
# After:  ens dibelin qui en larriere garde estoit escha
# Before: pa autresint ⁊ sen foi a sur . ⁊ renauz de sai
# After:  pa autresint ⁊ sen foi a sur . ⁊ renauz de sai
# Before: este fu pris et retenuz. en cele bataille fu la sainte
# After:  este fu pris et retenuz. en cele bataille fu la sainte
# Before: croiz perdue . ne ne sot len quele de
# After:  croiz perdue . ne ne sot len quele de
# Before: uint fors młt grand piece apres au tens que
# After:  uint fors młt grand piece apres au tens que
# Before: mon seigneur henri de champaigne estoit
# After:  mon seigneur henri de champaigne estoit
# Before: sires dacre . ⁊ de la t͛re que li crestien tenoient
# After:  sires dacre . ⁊ de la t̾re que li crestien tenoient
# Before: si uint a lui uns freres du temple qui en la
# After:  si uint a lui uns freres du temple qui en la
# Before: bataille auoit este . ⁊ si li dist sire sen sauoit
# After:  bataille auoit este . ⁊ si li dist sire sen sauoit
# Before: ne se len pooit trouer home en ceste t͛re qͥ me
# After:  ne se len pooit trouer home en ceste t̾re qͥ me
# Before: seust mener en la piece de t͛re ou la bataille
# After:  seust mener en la piece de t̾re ou la bataille
# Before: le fu. ⁊ cil dist que oil młr bien. ⁊ si sauroie
# After:  le fu. ⁊ cil dist que oil młr bien. ⁊ si sauroie
# Before: foi a mes mains endementres que la batail
# After:  foi a mes mains endementres que la batail
# Before: le fu. ⁊ cil dist que oil młr bien. ⁊ si sauroie
# After:  le fu. ⁊ cil dist que oil młr bien. ⁊ si sauroie
# Before: bien assener fet il en la piece de t͛re ou li rois
# After:  bien assener fet il en la piece de t̾re ou li rois
# Before: fu pris . lors cõmanda li quens quil i alast
# After:  fu pris . lors cõmanda li quens quil i alast
# Before: entre lui ⁊ le mestre du temple quar il li
# After:  entre lui ⁊ le mestre du temple quar il li
# Before: ot dit quil i avoit la croiz en foie. ⁊ si li dist
# After:  ot dit quil i avoit la croiz en foie. ⁊ si li dist
# Before: quil ni pooit aler se par lui non. ⁊ si coueno
# After:  quil ni pooit aler se par lui non. ⁊ si coueno
# Before: it aler de nuiz que se il i aloient de iourz il se
# After:  it aler de nuiz que se il i aloient de iourz il se
# Before: roient pris de par dieu alez i en tel point com
# After:  roient pris de par dieu alez i en tel point com
# Before: uous sauez quil i fet meillor aler il i alerẽt
# After:  uous sauez quil i fet meillor aler il i alerẽt
# Before: et si foirent bien par .iii. nuiz. ⁊ si ni trouue
# After:  et si foirent bien par .iii. nuiz. ⁊ si ni trouue
# Before: R uous dirai des sarrazins qui orent
# After:  R uous dirai des sarrazins qui orent
# Before: desconfit les crestiens ⁊ pris il se herber
# After:  desconfit les crestiens ⁊ pris il se herber
# Before: gierent. ⁊ salehadins rendi graces ⁊ merciz
# After:  gierent. ⁊ salehadins rendi graces ⁊ merciz
# Before: a ses diex de laneur quil li auoient feitez. ⁊
# After:  a ses diex de laneur quil li auoient feitez. ⁊
# Before: fist crier parmi lost quen li ẽuoiast en sa ter
# After:  fist crier parmi lost quen li ẽuoiast en sa ter
# Before: re touz les ch̃rs quil auoit pris. ⁊ len les ime
# After:  re touz les ch̃rs quil auoit pris. ⁊ len les ime
# Before: na si comanda quen amenast les barons et
# After:  na si comanda quen amenast les barons et
# Before: les hauz homes deuant lui len li amena le
# After:  les hauz homes deuant lui len li amena le
# Before: prince renaut de saiete apres li amena on
# After:  prince renaut de saiete apres li amena on
# Before: omfroi son fillastre apres li mestre du tem
# After:  omfroi son fillastre apres li mestre du tem
# Before: ple apres le marchis boniface de monferrãt
# After:  ple apres le marchis boniface de monferrãt
# Before: apres le conte iocelin apres le conte haymõ
# After:  apres le conte iocelin apres le conte haymõ
# Before: qui freres estoit le roi apres le mareschalle
# After:  qui freres estoit le roi apres le mareschalle
# Before: roi . Tuit cil haut home furent pris auec le
# After:  roi . Tuit cil haut home furent pris auec le
# Before: roi en la bataille. Ce iour fu samedi ⁊ feste
# After:  roi en la bataille. Ce iour fu samedi ⁊ feste
# Before: saint martin le boillant. quant salehadĩs
# After:  saint martin le boillant. quant salehadĩs
# Before: uit le roi ⁊ ses barons qui estoient ensam̃ ci
# After:  uit le roi ⁊ ses barons qui estoient ensam̃ ci
# Before: deuant lui en fu młt liez. ⁊ il uit que li rois
# After:  deuant lui en fu młt liez. ⁊ il uit que li rois
# Before: auoit chaut si beuroit uolentiers si fist apor
# After:  auoit chaut si beuroit uolentiers si fist apor
# Before: ter pleine coupe de sirop a boiure pour refroi
# After:  ter pleine coupe de sirop a boiure pour refroi
# Before: dier quant li rois ot beu si tendi la coupe ⁊
# After:  dier quant li rois ot beu si tendi la coupe ⁊
# Before: au conte renaut qui en coste lui seoit pour
# After:  au conte renaut qui en coste lui seoit pour
# Before: boiure. Quant salehadins uit quil auoit
# After:  boiure. Quant salehadins uit quil auoit
# Before: done a boiure au prince renaut si en fu mlłt
# After:  done a boiure au prince renaut si en fu mlłt
# Before: corrouciez quar ce estoit lome du monde q̃
# After:  corrouciez quar ce estoit lome du monde q̃
# Before: il haioit plus si en fu młt doulanz si dist au
# After:  il haioit plus si en fu młt doulanz si dist au
# Before: roi que ce pesoit lui que done li auoit. Mes
# After:  roi que ce pesoit lui que done li auoit. Mes
# Before: puis quil li auoit done bien le beust. Mes
# After:  puis quil li auoit done bien le beust. Mes
# Before: ce seroit par un couenant que james ne be
# After:  ce seroit par un couenant que james ne be
# Before: ura dautre que por nul auoir quen li se
# After:  ura dautre que por nul auoir quen li se
# Before: ust doner il ne le lesseroit plus uiure : quil
# After:  ust doner il ne le lesseroit plus uiure : quil
# Before: ne li copast la teste il meismes de sa main.
# After:  ne li copast la teste il meismes de sa main.
# Before: Pour ce que onques foi ne serement ne litĩt
# After:  Pour ce que onques foi ne serement ne litĩt
# Before: de triues quil li donast. Quant li princes re
# After:  de triues quil li donast. Quant li princes re
# Before: nauz ot beu si le fist salehadins prendre ⁊ me
# After:  nauz ot beu si le fist salehadins prendre ⁊ me
# Before: ner hors de sa tente si demanda une espee et
# After:  ner hors de sa tente si demanda une espee et
# Before: len li aporta . il la prist si li coupa la teste et
# After:  len li aporta . il la prist si li coupa la teste et
# Before: puis si fist prendre la teste ⁊ comanda que ele
# After:  puis si fist prendre la teste ⁊ comanda que ele
# Before: fust trainee par toutes les citez et par touz les
# After:  fust trainee par toutes les citez et par touz les
# Before: chastiaus de sa t͛re et ele si fu. Quant saleha
# After:  chastiaus de sa t̾re et ele si fu. Quant saleha
# Before: dins ot coupee au prince renaut la teste si ⁊
# After:  dins ot coupee au prince renaut la teste si ⁊
# Before: fist prendre le roi ⁊ touz les prisoniers si les
# After:  fist prendre le roi ⁊ touz les prisoniers si les
# Before: enuoia a damas en prison ⁊ se parti dileques.
# After:  enuoia a damas en prison ⁊ se parti dileques.
# Before: ⁊ sen ala logier deuant tabarie. quant la cõ
# After:  ⁊ sen ala logier deuant tabarie. quant la cõ
# Before: sot que li rois estoit pris . ⁊ que li crestien
# After:  sot que li rois estoit pris . ⁊ que li crestien
# Before: estoient desconfit si rendi tabarie a salehadin.
# After:  estoient desconfit si rendi tabarie a salehadin.
# Before: Cel iour meismes enuoia salehadins a na
# After:  Cel iour meismes enuoia salehadins a na
# Before: zareth. ⁊ li rendi len ce iour que la desconfitu
# After:  zareth. ⁊ li rendi len ce iour que la desconfitu
# Before: re fu Ces .ii. citez le mescredi ala a acre si li ren
# After:  re fu Ces .ii. citez le mescredi ala a acre si li ren
# Before: di len. apres ala a sur si ne la uout pas asegier.
# After:  di len. apres ala a sur si ne la uout pas asegier.
# Before: pour ce que en cor estoit ch̃rie dedenz qui de ⁊
# After:  pour ce que en cor estoit ch̃rie dedenz qui de ⁊
# Before: la bataille furent eschape. Or uint balien dy
# After:  la bataille furent eschape. Or uint balien dy
# Before: belin qui dedenz sur estoit . si manda a saleha
# After:  belin qui dedenz sur estoit . si manda a saleha
# Before: din quil li donast conduit daler en ierusalẽ
# After:  din quil li donast conduit daler en ierusalẽ
# Before: pour amener la roine sa fame ⁊ ses enfanz.
# After:  pour amener la roine sa fame ⁊ ses enfanz.
# Before: ⁊ il li dona uolentiers par si quen ierusalẽ
# After:  ⁊ il li dona uolentiers par si quen ierusalẽ
# Before: uois chantoient en ceste maniere bien
# After:  uois chantoient en ceste maniere bien
# Before: .vii. fois . Alujtisme chant si rompirẽt
# After:  .vii. fois . Alujtisme chant si rompirẽt
# Before: si qujl me fu aujs que il chaissent en a
#
# After:  si qujl me fu aujs que il chaissent en a
#
# Before: bisme.Et lors me fu aujs que tous les
#
# After:  bisme.Et lors me fu aujs que tous les
#
# Before: eles des oiseaus uolans uoloient deuerz
#
# After:  eles des oiseaus uolans uoloient deuerz
#
# Before: moi.a grant raujne.
#
# After:  moi.a grant raujne.
#
# Before: t quant les uois sen aloient si
#
# After:  t quant les uois sen aloient si
#
# Before: remest la grant odours que
#
# After:  remest la grant odours que
#
# Before: iou auoie deuant sentie. et que tant
#
# After:  iou auoie deuant sentie. et que tant
#
# Before: me auoit deuant pleu. Ensi remest li
#
# After:  me auoit deuant pleu. Ensi remest li
#
# Before: chans. et iou comenchai a penser a
#
# After:  chans. et iou comenchai a penser a
#
# Before: ceste merueille.Atant es vous vne
#
# After:  ceste merueille.Atant es vous vne
#
# Before: vois . qui me dist . laisse a penser. si
#
# After:  vois . qui me dist . laisse a penser. si
#
# Before: rent graces a ton creator ce que tu li
#
# After:  rent graces a ton creator ce que tu li
#
# Before: dois.Lors me leuai et iij. qujl estoit
#
# After:  dois.Lors me leuai et iij. qujl estoit
#
# Before: nonne passe del iour. Et lors oi iou
#
# After:  nonne passe del iour. Et lors oi iou
#
# Before: grant meruelle.que ie qujdoie qujl
#
# After:  grant meruelle.que ie qujdoie qujl
#
# Before: fust encore matin. por ce que iesgar
#
# After:  fust encore matin. por ce que iesgar
#
# Before: doie el liuret. qui tant me plaisoit. si
#
# After:  doie el liuret. qui tant me plaisoit. si
#
# Before: comenchai le serujce tel com il afiert
#
# After:  comenchai le serujce tel com il afiert
#
# Before: acel ior.que il rechut mort por nous.
#
# After:  acel ior.que il rechut mort por nous.
#
# Before: Et por ce ne le sacreonmie.Car la figure
#
# After:  Et por ce ne le sacreonmie.Car la figure
#
# Before: doit estre ariere mise iusques au diemẽ
#
# After:  doit estre ariere mise iusques au diemẽ
#
# Before: che. Mais on le sacre tous les autres
#
# After:  che. Mais on le sacre tous les autres
#
# Before: ious. en ramenbrance quil fu sacrefies
#
# After:  ious. en ramenbrance quil fu sacrefies
#
# Before: Et a cel ior fu il vraiement sacrefies.
#
# After:  Et a cel ior fu il vraiement sacrefies.
#
# Before: Ce est li venredi ueneois. Acel iour
#
# After:  Ce est li venredi ueneois. Acel iour
#
# Before: ne le sacre on point que il na point de se
#
# After:  ne le sacre on point que il na point de se
#
# Before: nefiance que li iors est venus que il
#
# After:  nefiance que li iors est venus que il
#
# Before: fu crucefies.Et quant iou oi fait le
#
# After:  fu crucefies.Et quant iou oi fait le
#
# Before: seruice de diu ole aide de dieu. et iou voel
#
# After:  seruice de diu ole aide de dieu. et iou voel
#
# Before: recheuoir mon saueor.si vint vns ange
#
# After:  recheuoir mon saueor.si vint vns ange
#
# Before: les deuant moi. quj me prist ꝑ les .ii.
#
# After:  les deuant moi. quj me prist ꝑ les .ii.
#
# Before: mains. si me dist en tel manieres.
#
# After:  mains. si me dist en tel manieres.
#
# Before: es .iii. parties te sunt vees
#
# After:  es .iii. parties te sunt vees
#
# Before: a recheuoir dessi la que ie
#
# After:  a recheuoir dessi la que ie
#
# Before: taie fait a entendre qu elles
#
# After:  taie fait a entendre qu elles
#
# Before: senefient or soies seus. Apres cel mot
#
# After:  senefient or soies seus. Apres cel mot
#
# Before: me leuai en haut et me porta en tel liu
#
# After:  me leuai en haut et me porta en tel liu
#
# Before: que se toutes les langues parloient et
#
# After:  que se toutes les langues parloient et
#
# Before: tout li cuer mortel pensoient et les
#
# After:  tout li cuer mortel pensoient et les
#
# Before: orelles escoutoient. ne poroient il pas cõ
#
# After:  orelles escoutoient. ne poroient il pas cõ
#
# Before: prendre tantes ioies. quil nen ieust .Cͫ.
#
# After:  prendre tantes ioies. quil nen ieust .Cͫ.
#
# Before: tans en celuj. Et se ie disoie que ce fu au
#
# After:  tans en celuj. Et se ie disoie que ce fu au
#
# Before: tierc chiel la ou sains pols fu poses.si ne
#
# After:  tierc chiel la ou sains pols fu poses.si ne
#
# Before: qujderoie ie pas mentir. Mais ie ne
#
# After:  qujderoie ie pas mentir. Mais ie ne
#
# Before: men voel pas vanter. mais itant pujs
#
# After:  men voel pas vanter. mais itant pujs
#
# Before: ie bien dire.que la me fu descouuerte
#
# After:  ie bien dire.que la me fu descouuerte
#
# Before: li ceptres dont saint pols dist que nu
#
# After:  li ceptres dont saint pols dist que nu
#
# Before: le langue morteux ne doit descouurir.
#
# After:  le langue morteux ne doit descouurir.
#
# Before: t quant ioi oi tantes meruel
#
# After:  t quant ioi oi tantes meruel
#
# Before: les esgardees. si mapiela. li an
#
# After:  les esgardees. si mapiela. li an
#
# Before: geles me dist. astu grans ho
#
# After:  geles me dist. astu grans ho
#
# Before: nors. et grans meruelles veues. Et
#
# After:  nors. et grans meruelles veues. Et
#
# Before: iou dis que iou ne qujdoie mie que nu
#
# After:  iou dis que iou ne qujdoie mie que nu
#
# Before: les si grans peussent estre.et il me dist
#
# After:  les si grans peussent estre.et il me dist
#
# Before: que il me monsterroit encore gring
#
# After:  que il me monsterroit encore gring
#
# Before: nors. Lors me prist et me mena en
#
# After:  nors. Lors me prist et me mena en
#
# Before: core en .i. estrange estage quj estoit a
#
# After:  core en .i. estrange estage quj estoit a
#
# Before: cent doubles plus clers que uoirres et
#
# After:  cent doubles plus clers que uoirres et
#
# Before: estoit coulores plus que nus cuers ne
#
# After:  estoit coulores plus que nus cuers ne
#
# Before: poroit penser . et illueques me monstra
#
# After:  poroit penser . et illueques me monstra
#
# Before: il le force de la trinite apiertement que
#
# After:  il le force de la trinite apiertement que
#
# Before: ie uj deujseement le pere et le fil et le
#
# After:  ie uj deujseement le pere et le fil et le
#
# Before: saint esperit.Et si uj que ces .iii. per
#
# After:  saint esperit.Et si uj que ces .iii. per
#
# Before: sonnes repairoient a vne deite.et a
#
# After:  sonnes repairoient a vne deite.et a
#
# Before: vne possance.Et ne porquant se iou
#
# After:  vne possance.Et ne porquant se iou
#
# Before: ai dit que iou ai veu les .iii. Lune
#
# After:  ai dit que iou ai veu les .iii. Lune
#
# Before: deuisee del autre. Ja por ce ne me cor
#
# After:  deuisee del autre. Ja por ce ne me cor
#
# Before: ront sus li envieus quj ne sieruent
#
# After:  ront sus li envieus quj ne sieruent
#
# Before: fors que des autres reprendre. ne por
#
# After:  fors que des autres reprendre. ne por
#
# Before: ce ne dient il il mie que ie aie ale en
#
# After:  ce ne dient il il mie que ie aie ale en
#
# Before: contre l auctorite saint iehan le haut
#
# After:  contre l auctorite saint iehan le haut
#
# Before: euuangeliste qui dist que nus hom
#
# After:  euuangeliste qui dist que nus hom
#
# Before: morteus ne ujt onques le pere ne veir
#
# After:  morteus ne ujt onques le pere ne veir
#
# Before: ne le puet et ie mi acort bien.
#
# After:  ne le puet et ie mi acort bien.
#
# Before: ais tout chil qui lont oi nel
#
# After:  ais tout chil qui lont oi nel
#
# Before: ont pas bien entendu. car
#
# After:  ont pas bien entendu. car
#
# Before: il dist des homes morteux. Mais pujs
#
# After:  il dist des homes morteux. Mais pujs
#
# Before: uois chantoient en ceste maniere bien
# After:  uois chantoient en ceste maniere bien
# Before: et excercitans nouuelles choses ⁊
# After:  et excercitans nouuelles choses ⁊
# Before: merueilleuses et auoit o soi mise
# After:  merueilleuses et auoit o soi mise
# Before: ricorde. Cõme il feist merueilles
# After:  ricorde. Cõme il feist merueilles
# Before: il souffri felonnesses choses. Mes
# After:  il souffri felonnesses choses. Mes
# Before: sains Bernars oppose en autre ma
# After:  sains Bernars oppose en autre ma
# Before: niere et dist que nous labourons
#
# After:  niere et dist que nous labourons
#
# Before: chietiuement en .iiii. maladies.
#
# After:  chietiuement en .iiii. maladies.
#
# Before: Car nous sõmes legieremẽt sou
#
# After:  Car nous sõmes legieremẽt sou
#
# Before: duit et sõmes foibles a ouurer ⁊
#
# After:  duit et sõmes foibles a ouurer ⁊
#
# Before: fresles a contrester. Car se nous
#
# After:  fresles a contrester. Car se nous
#
# Before: uoulons fere difference entre le
#
# After:  uoulons fere difference entre le
#
# Before: bien ⁊ le mal nous sommes deceu.
#
# After:  bien ⁊ le mal nous sommes deceu.
#
# Before: Et ce nous nous essaions de fere
#
# After:  Et ce nous nous essaions de fere
#
# Before: bien nous defaillons . et nous se noꝰ
#
# After:  bien nous defaillons . et nous se noꝰ
#
# Before: efforccons a faire mal nous sõmes
#
# After:  efforccons a faire mal nous sõmes
#
# Before: seurmontee. Et pour ce fu neces
#
# After:  seurmontee. Et pour ce fu neces
#
# Before: saire li auenement du sauueeur.
#
# After:  saire li auenement du sauueeur.
#
# Before: que il habitans en nous enlumi
#
# After:  que il habitans en nous enlumi
#
# Before: noit nostre auuglesce. Et porce
#
# After:  noit nostre auuglesce. Et porce
#
# Before: que il manans en nous face aide
#
# After:  que il manans en nous face aide
#
# Before: en ñre maladie. Et pour ce que il
#
# After:  en ñre maladie. Et pour ce que il
#
# Before: estans pour nous deffendre nr̃e
#
# After:  estans pour nous deffendre nr̃e
#
# Before: fragilite et bataillans. § En
#
# After:  fragilite et bataillans. ⁋ En
#
# Before: uiron le secont auenement. Ce
#
# After:  uiron le secont auenement. Ce
#
# Before: est a sauoir au iugement sont
#
# After:  est a sauoir au iugement sont
#
# Before: aueoir .ii. choses. Cest a sauoir
#
# After:  aueoir .ii. choses. Cest a sauoir
#
# Before: les choses qui auendront auãt
#
# After:  les choses qui auendront auãt
#
# Before: le iugement et celles qui lacom
#
# After:  le iugement et celles qui lacom
#
# Before: paingneront. Trois choses sõt
#
# After:  paingneront. Trois choses sõt
#
# Before: qui uendront deuant cest a sa
#
# After:  qui uendront deuant cest a sa
#
# Before: uoir signe espoentable. la fail
#
# After:  uoir signe espoentable. la fail
#
# Before: lance de antecrist et lauenemẽt
#
# After:  lance de antecrist et lauenemẽt
#
# Before: ⁊ la doutance du feu . signe espoẽ
#
# After:  ⁊ la doutance du feu . signe espoẽ
#
# Before: table qui uendront deuant le
#
# After:  table qui uendront deuant le
#
# Before: iugement et celes qui lacõpain
#
# After:  iugement et celes qui lacõpain
#
# Before: gneront. § Trois choses sont
#
# After:  gneront. ⁋ Trois choses sont
#
# Before: deuant le iugement sont .v.
#
# After:  deuant le iugement sont .v.
#
# Before: lut̾ .xxi. Signe seront ou soleill
#
# After:  lut̾ .xxi. Signe seront ou soleill
#
# Before: ⁊ en la lune et es estoilles . ⁊ en
#
# After:  ⁊ en la lune et es estoilles . ⁊ en
#
# Before: la terre prise de gens par la con
#
# After:  la terre prise de gens par la con
#
# Before: fusion du son de la mer ⁊ des fleu
#
# After:  fusion du son de la mer ⁊ des fleu
#
# Before: ues. Les .iii. signes sont de termi
#
# After:  ues. Les .iii. signes sont de termi
#
# Before: nez alapocalipce .vii. Li soleus
#
# After:  nez alapocalipce .vii. Li soleus
#
# Before: est fait noir aussi cõme sanc de
#
# After:  est fait noir aussi cõme sanc de
#
# Before: cilis. Et la lune est faite aussi
#
# After:  cilis. Et la lune est faite aussi
#
# Before: cõme sanc. Et les estoilles du
#
# After:  cõme sanc. Et les estoilles du
#
# Before: ciel sont cheues aussi conme
#
# After:  ciel sont cheues aussi conme
#
# Before: sus la terre. Li soleus est dit obs
#
# After:  sus la terre. Li soleus est dit obs
#
# Before: curs quant a la priuacion de sa
#
# After:  curs quant a la priuacion de sa
#
# Before: lumiere aussi conme la mesme
#
# After:  lumiere aussi conme la mesme
#
# Before: e est mate et ploreuse quant
#
# After:  e est mate et ploreuse quant
#
# Before: le seigneur muert ou quant
#
# After:  le seigneur muert ou quant
#
# Before: au regart de greingneur lumie
#
# After:  au regart de greingneur lumie
#
# Before: re est dist obscurs. Cest a sauoir
#
# After:  re est dist obscurs. Cest a sauoir
#
# Before: de la clartee de jhesu crist ou qnͣt
#
# After:  de la clartee de jhesu crist ou qnͣt
#
# Before: a la comparoison de la parolle me
#
# After:  a la comparoison de la parolle me
#
# Before: thafore. Car la ueniance deuine
#
# After:  thafore. Car la ueniance deuine
#
# Before: sera si cruelle que li soleus ne lo
#
# After:  sera si cruelle que li soleus ne lo
#
# Before: sera regarder. § Cest a sauoir
#
# After:  sera regarder. ⁋ Cest a sauoir
#
# Before: que le ciel que nous apelõs ciel
#
# After:  que le ciel que nous apelõs ciel
#
# Before: est dit cieus . dair et les estoil
#
# After:  est dit cieus . dair et les estoil
#
# Before: les sont apelees asub . les queles
#
# After:  les sont apelees asub . les queles
#
# Before: ont semblances destoilles et sõt
#
# After:  ont semblances destoilles et sõt
#
# Before: dites cheoir du ciel selonc lopi
#
# After:  dites cheoir du ciel selonc lopi
#
# Before: nion du pueple. Qnͣt asub descẽ
#
# After:  nion du pueple. Qnͣt asub descẽ
#
# Before: di dont lescripture se conferme
#
# After:  di dont lescripture se conferme
#
# Before: en la conmune maniere de ꝑler.
#
# After:  en la conmune maniere de ꝑler.
#
# Before: Et adonques maieurment sera
#
# After:  Et adonques maieurment sera
#
# Before: faite telz impressions. Car la quͣ
#
# After:  faite telz impressions. Car la quͣ
#
# Before: litee du feu habondera et ses choses
#
# After:  litee du feu habondera et ses choses
#
# Before: fera nr̃e sires pour les pecheeurs
#
# After:  fera nr̃e sires pour les pecheeurs
#
# Before: espoenter. Aucuns dient q̃ les
#
# After:  espoenter. Aucuns dient q̃ les
#
# Before: estoilles chieent du ciel qnͣt elles
#
# After:  estoilles chieent du ciel qnͣt elles
#
# Before: sont dehors ausi cõme feu. Ou
#
# After:  sont dehors ausi cõme feu. Ou
#
# Before: quant plusieurs qui erent ape
#
# After:  quant plusieurs qui erent ape
#
# Before: lez estoilles de sainte eglise chie
#
# After:  lez estoilles de sainte eglise chie
#
# Before: ent ou quant les estoilles retͣiẽt
#
# After:  ent ou quant les estoilles retͣiẽt
#
# Before: leur lumiere pour ce que elles
#
# After:  leur lumiere pour ce que elles
#
# Before: ne soient ueues. § Du quart
#
# After:  ne soient ueues. ⁋ Du quart
#
# Before: signe duquel on list que prise
#
# After:  signe duquel on list que prise
#
# Before: de gens sera en terre si conme
#
# After:  de gens sera en terre si conme
#
# Before: saint mathieu dist .xxiiii. Adõ
#
# After:  saint mathieu dist .xxiiii. Adõ
#
# Before: ques sera tribulacion tele que
#
# After:  ques sera tribulacion tele que
#
# Before: il ne fust tele des le conmencemẽt
#
# After:  il ne fust tele des le conmencemẽt
#
# Before: du monde et c̾. § Le quint sig
#
# After:  du monde et c̾. ⁋ Le quint sig
#
# Before: ne est a sauoir la confusion de
#
# After:  ne est a sauoir la confusion de
#
# Before: la mer aucuns estimens que la
#
# After:  la mer aucuns estimens que la
#
# Before: mer penra auec grant freour
#
# After:  mer penra auec grant freour
#
# Before: ainsi que ele naura mie la qua
#
# After:  ainsi que ele naura mie la qua
#
# Before: litee ancienne selonc ce que dit
#
# After:  litee ancienne selonc ce que dit
#
# Before: saint Jehan en lapocalipce .xxi.
#
# After:  saint Jehan en lapocalipce .xxi.
#
# Before: et la mer ia non est ou selonc
#
# After:  et la mer ia non est ou selonc
#
# Before: les autres. Cil sons sera quant
#
# After:  les autres. Cil sons sera quant
#
# Before: la mer sesleuera .xl. coutes desus
#
# After:  la mer sesleuera .xl. coutes desus
#
# Before: les montaingnes. et ce ne se
#
# After:  les montaingnes. et ce ne se
#
# Before: ra mie sans grant murmure.
#
# After:  ra mie sans grant murmure.
#
# Before: Et apres ce se descroistra selõc
#
# After:  Et apres ce se descroistra selõc
#
# Before: ce que dist saint gregoire adon
#
# After:  ce que dist saint gregoire adon
#
# Before: ques seront faites nouuelles
#
# After:  ques seront faites nouuelles
#
# Before: choses et qui ne furent onq̃s oies
#
# After:  choses et qui ne furent onq̃s oies
#
# Before: Cest a sauoir la parturbacion de
#
# After:  Cest a sauoir la parturbacion de
#
# Before: la mer et des ondes. § Certes
#
# After:  la mer et des ondes. ⁋ Certes
#
# Before: saint iheroisme trouua es avẽs
#
# After:  saint iheroisme trouua es avẽs
#
# Before: .iii. des hebrieux ou .xv. signe
#
# After:  .iii. des hebrieux ou .xv. signe
#
# Before: precedencia iudicium. Mes il
#
# After:  precedencia iudicium. Mes il
#
# Before: ne expresse mie ce ces choses vẽ
#
# After:  ne expresse mie ce ces choses vẽ
#
# Before: dront continuelment ou en di
#
# After:  dront continuelment ou en di
#
# Before: uers temps. § Le premeraĩ
#
# After:  uers temps. ⁋ Le premeraĩ
#
# Before: iour se esleuera la mer .lx. cou
#
# After:  iour se esleuera la mer .lx. cou
#
# Before: tes desus la mer hautesce des
#
# After:  tes desus la mer hautesce des
#
# Before: montaingnes et demoura en
#
# After:  montaingnes et demoura en
#
# Before: son leu ausi cõme murs.  § Le
#
# After:  son leu ausi cõme murs.  ⁋ Le
#
# Before: secont iour descroistra tant q̃
#
# After:  secont iour descroistra tant q̃
#
# Before: a painnes la pourra on ueoir.
#
# After:  a painnes la pourra on ueoir.
#
# Before: §Le tiers iour les bestes ma
#
# After:  ⁋Le tiers iour les bestes ma
#
# Before: rines apparront sus la mer et
#
# After:  rines apparront sus la mer et
#
# Before: donront muiement iusques au
#
# After:  donront muiement iusques au
#
# Before: ciel et deux entendra seulemẽt
#
# After:  ciel et deux entendra seulemẽt
#
# Before: les uois et les muiemens. § Le
#
# After:  les uois et les muiemens. ⁋ Le
#
# Before: quart iour ardra a touz iours
#
# After:  quart iour ardra a touz iours
#
# Before: mes la mer. et lyaue et le muiemẽt
#
# After:  mes la mer. et lyaue et le muiemẽt
#
# Before: de celes bestes. § Le quint ior
#
# After:  de celes bestes. ⁋ Le quint ior
#
# Before: li arbre et les herbes donront
#
# After:  li arbre et les herbes donront
#
# Before: rousee de sanc. En ce quint ior
#
# After:  rousee de sanc. En ce quint ior
#
# Before: ainsi com li autre dient se amas
#
# After:  ainsi com li autre dient se amas
#
# Before: seront tuit li oissel du ciel aus
#
# After:  seront tuit li oissel du ciel aus
#
# Before: chans chascun oissel en son ordre
#
# After:  chans chascun oissel en son ordre
#
# Before: ⁊ ne mengeront ne ne buuront
#
# After:  ⁊ ne mengeront ne ne buuront
#
# Before: ainz redouteront moult le pro
#
# After:  ainz redouteront moult le pro
#
# Before: chain iugement. § Ou sisies
#
# After:  chain iugement. ⁋ Ou sisies
#
# Before: me jour trebucheront les edefi
#
# After:  me jour trebucheront les edefi
#
# Before: ces. En ce sisiesme iour si ꝯme
#
# After:  ces. En ce sisiesme iour si ꝯme
#
# Before: on dist sourdront fluns de feu
#
# After:  on dist sourdront fluns de feu
#
# Before: devers occident contre la face
#
# After:  devers occident contre la face
#
# Before: du firmament et courront ius
#
# After:  du firmament et courront ius
#
# Before: ques en orient. § Du septies
#
# After:  ques en orient. ⁋ Du septies
#
# Before: me iour se hurteront les pierres
#
# After:  me iour se hurteront les pierres
#
# Before: lune contre lautre ⁊ se fendrõt
#
# After:  lune contre lautre ⁊ se fendrõt
#
# Before: en .iiii. parties et chascune ꝑtie
#
# After:  en .iiii. parties et chascune ꝑtie
#
# Before: hurtera lautre ainsi com len dit.
#
# After:  hurtera lautre ainsi com len dit.
#
# Before: Et nuls homs mortel ne saura
#
# After:  Et nuls homs mortel ne saura
#
# Before: ce son fors que dieu tant seule
#
# After:  ce son fors que dieu tant seule
#
# Before: ment. § En luitiesme iour
#
# After:  ment. ⁋ En luitiesme iour
#
# Before: sera general mouement de t̾re
#
# After:  sera general mouement de t̾re
#
# Before: mistrent les anemis a lempire sans sãc
# After:  mistrent les anemis a lempire sans sãc
# Before: espandre. ⁊ donc retornerent a lemperie
# After:  espandre. ⁊ donc retornerent a lemperie
# Before: re ⁊ furent receus honnorablement.
# After:  re ⁊ furent receus honnorablement.
# Before: § Et donc aucuns orent enuie des biẽs
# After:  ⁋ Et donc aucuns orent enuie des biẽs
# Before: de ces princes. Si distrent en traison a
# After:  de ces princes. Si distrent en traison a
# Before: lemperiere. Et firent tant par prieres
# After:  lemperiere. Et firent tant par prieres
# Before: ⁊ par dons. que il furent accusez fausse
# After:  ⁊ par dons. que il furent accusez fausse
# Before: ment du blasme de sa maieste. Et qũt
# After:  ment du blasme de sa maieste. Et qũt
# Before: il fu dit a lemperiere il fu plain de gnͣt
# After:  il fu dit a lemperiere il fu plain de gnͣt
# Before: forssenerie. Et ꝯmanda quil fussent i
# After:  forssenerie. Et ꝯmanda quil fussent i
# Before: mis en chartre. Et sanz nule autre de
# After:  mis en chartre. Et sanz nule autre de
# Before: mande faire. il ꝯmanda que il fussent
# After:  mande faire. il ꝯmanda que il fussent
# Before: occis cele nuit. Et quant il le sorent par
# After:  occis cele nuit. Et quant il le sorent par
# Before: le portier qui les gardoit. il des_rompirẽt
# After:  le portier qui les gardoit. il des-rompirẽt
# Before: leur vestemens ⁊ pleurerent amerem̃t
# After:  leur vestemens ⁊ pleurerent amerem̃t
# Before: Et donc nepoticien si se remenbra ꝯmẽt
# After:  Et donc nepoticien si se remenbra ꝯmẽt
# Before: le beneoit nicholas auoit delivre les .iii.
# After:  le beneoit nicholas auoit delivre les .iii.
# Before: innocens. Si amõnesta les autres que
# After:  innocens. Si amõnesta les autres que
# Before: il requeissent leur aide son aide. Et si
# After:  il requeissent leur aide son aide. Et si
# Before: ꝯme il oroient. S̃ nicholas sapparut a
# After:  ꝯme il oroient. S̃ nicholas sapparut a
# Before: eulz. ⁊ si sapparut a constantin emperie
# After:  eulz. ⁊ si sapparut a constantin emperie
# Before: re⁊ li dist: pour quoi as tu prisi ces prin
# After:  re⁊ li dist: pour quoi as tu prisi ces prin
# Before: ces a si grant tort. ⁊ les as iugiez a mort
# After:  ces a si grant tort. ⁊ les as iugiez a mort
# Before: sanz meffait Lieue sus hastiuement
# After:  sanz meffait Lieue sus hastiuement
# Before: ⁊ꝯmande quil soient lessiez. Et se ce nõ
# After:  ⁊ꝯmande quil soient lessiez. Et se ce nõ
# Before: ie prie a dieu que il esmueue bataille ꝯ
# After:  ie prie a dieu que il esmueue bataille ꝯ
# Before: tre toi. en laquele tu trebuches. ⁊ soies
# After:  tre toi. en laquele tu trebuches. ⁊ soies
# Before: fait viande as bestes. Et lemperiere
# After:  fait viande as bestes. Et lemperiere
# Before: li demanda: qui es tu qui es entre par
# After:  li demanda: qui es tu qui es entre par
# Before: nuit en mon palais et moses dire tiex
# After:  nuit en mon palais et moses dire tiex
# Before: paroles Et il li dist: Je sui nicholas e
# After:  paroles Et il li dist: Je sui nicholas e
# Before: uesque de la cite de Mierre. Et aussi es
# After:  uesque de la cite de Mierre. Et aussi es
# Before: poenta il le preuost disant. Tu qui as
# After:  poenta il le preuost disant. Tu qui as
# Before: sens ⁊ pensee perdue pour quoi as tu
# After:  sens ⁊ pensee perdue pour quoi as tu
# Before: ꝯsentu en la mort de ces innocens Va
# After:  ꝯsentu en la mort de ces innocens Va
# Before: tost ⁊ pense de deliurer les. ou se ce nõ
# After:  tost ⁊ pense de deliurer les. ou se ce nõ
# Before: ton ton cors sera peri ⁊ porri de vers. ⁊
# After:  ton ton cors sera peri ⁊ porri de vers. ⁊
# Before: ta mesniee sera tantost destruite. Et
# After:  ta mesniee sera tantost destruite. Et
# Before: il li demanda: qui es tu qui si nous me
# After:  il li demanda: qui es tu qui si nous me
# Before: naces tant Et il dist: saches que ie
# After:  naces tant Et il dist: saches que ie
# Before: sui nicholas euesque de la cite de Mi
# After:  sui nicholas euesque de la cite de Mi
# Before: erre. Et donc sesueilla lun ⁊ lautre
# After:  erre. Et donc sesueilla lun ⁊ lautre
# Before: ⁊ distrent lun a lautre leur songe
# After:  ⁊ distrent lun a lautre leur songe
# Before: ⁊ manderent tantost ces en char
# After:  ⁊ manderent tantost ces en char
# Before: tres. Et lemperiere leur dist: qͥ ex
# After:  tres. Et lemperiere leur dist: qͥ ex
# Before: ars magiques sauez vous qui nous
# After:  ars magiques sauez vous qui nous
# Before: auez en nuit tant eslusez ꝑ songes
# After:  auez en nuit tant eslusez ꝑ songes
# Before: Et il respondirent que il nestoient pas
# After:  Et il respondirent que il nestoient pas
# Before: enchanteurs. ⁊ si nauoient pas deser
# After:  enchanteurs. ⁊ si nauoient pas deser
# Before: ui sentence de mort. Et donc dist lem
# After:  ui sentence de mort. Et donc dist lem
# Before: periere: Congnoissiez vous .i. hõme
# After:  periere: Congnoissiez vous .i. hõme
# Before: qui a non nicholas Et qũt il oirẽt
# After:  qui a non nicholas Et qũt il oirẽt
# Before: ce non. il tendirent les mains auci
# After:  ce non. il tendirent les mains auci
# Before: ciel et prierent nostre seigneur q̃
# After:  ciel et prierent nostre seigneur q̃
# Before: par les prieres ⁊ les merites de saint
# After:  par les prieres ⁊ les merites de saint
# Before: nicholas. il les deliurast de ce peril
# After:  nicholas. il les deliurast de ce peril
# Before: present. Et quant lemperiere out
# After:  present. Et quant lemperiere out
# Before: oï diceulz la vie ⁊ les miracles du be
# After:  oï diceulz la vie ⁊ les miracles du be
# Before: neoit nicholas. et adonc il leur dist:
# After:  neoit nicholas. et adonc il leur dist:
# Before: alez vous en ⁊ rendez graces a dieu
# After:  alez vous en ⁊ rendez graces a dieu
# Before: qui vous a deliures ꝑ les prieres de ce
# After:  qui vous a deliures ꝑ les prieres de ce
# Before: li nicholas. Et li aportes de vos ioi
# After:  li nicholas. Et li aportes de vos ioi
# Before: es et li pries que il ne me menace
# After:  es et li pries que il ne me menace
# Before: plus mes prie pour moi ⁊ pour mõ
# After:  plus mes prie pour moi ⁊ pour mõ
# Before: regne a nostre seigneur. Et pou de
# After:  regne a nostre seigneur. Et pou de
# Before: iours apres les deuant dis princes
# After:  iours apres les deuant dis princes
# Before: alerent au seriant de dieu ⁊ sageno
# After:  alerent au seriant de dieu ⁊ sageno
# Before: illierent a ses pies. humblement.
# After:  illierent a ses pies. humblement.
# Before: disans: Vraiement es tu seriant de
# After:  disans: Vraiement es tu seriant de
# Before: dieu ⁊ vrai aoureur ⁊ ameur de ihe
# After:  dieu ⁊ vrai aoureur ⁊ ameur de ihe
# Before: sucrist. Et quant il li orent tout
# After:  sucrist. Et quant il li orent tout
# Before: conte par ordre. il leua les mains
# After:  conte par ordre. il leua les mains
# Before: au ciel. ⁊ rendi grans loenges a di
# After:  au ciel. ⁊ rendi grans loenges a di
# Before: eu. ⁊ renuoia les princes bien en
# After:  eu. ⁊ renuoia les princes bien en
# Before: seigniez en leur païs. Et qũt no
# After:  seigniez en leur païs. Et qũt no
# Before: stre seigneur le voult prendre il
# After:  stre seigneur le voult prendre il
# Before: depria dieu que il li enuoiast ses ã
# After:  depria dieu que il li enuoiast ses ã
# Before: gres. Et il enclina le chief ⁊ vit les
# After:  gres. Et il enclina le chief ⁊ vit les
# Before: angres venans a li. Et il dist le psi
# After:  angres venans a li. Et il dist le psi
# Before: aume: Sire iai espere en toiiusques
# After:  aume: Sire iai espere en toiiusques
# Before: a ce vers. Sire ie ꝯmande mon espe
# After:  a ce vers. Sire ie ꝯmande mon espe
# Before: rit en tes mains. Et donc rendi les
# After:  rit en tes mains. Et donc rendi les
# Before: perit en lan de nostre seigneur .CCC.
# After:  perit en lan de nostre seigneur .CCC.
# Before: ⁊ .xliij. a g̃nt melodie dicte des cele
# After:  ⁊ .xliij. a g̃nt melodie dicte des cele
# Before: stiex compaignies. Et qũt il fu en
# After:  stiex compaignies. Et qũt il fu en
# Before: seueli en vne tombe de marbre vne
# After:  seueli en vne tombe de marbre vne
# Before: fontaine duile decourut du cheues
# After:  fontaine duile decourut du cheues
# Before: ⁊vne dyaue des piez. Et iusques a
# After:  ⁊vne dyaue des piez. Et iusques a
# Before: cest iour dui il ist de ses membres
# After:  cest iour dui il ist de ses membres
# Before: huile sainte qui vaut au salu de
# After:  huile sainte qui vaut au salu de
# Before: Ci cõmence le premier volume du mireoir hystorial translate en francois
# After:  Ci cõmence le premier volume du mireoir hystorial translate en francois
# Before: Our ce que oy
# After:  Our ce que oy
# Before: seuse est chose
# After:  seuse est chose
# Before: nuysant et at
# After:  nuysant et at
# Before: traiement de
# After:  traiement de
# Before: tous vices se
# After:  tous vices se
# Before: lonc ce q̃ mesẜ
# After:  lonc ce q̃ mesẜ
# Before: saint Jerosme
# After:  saint Jerosme
# Before: tesmoigne en
# After:  tesmoigne en
# Before: ses auctorites recitees en pluseurs
# After:  ses auctorites recitees en pluseurs
# Before: liures de diuinite . Et ouide meismes
# After:  liures de diuinite . Et ouide meismes
# Before: dit ou liure de remedies . que qui
# After:  dit ou liure de remedies . que qui
# Before: veult fouir et eschiuer les ars de
# After:  veult fouir et eschiuer les ars de
# Before: vices et de pechie il doit oster oiseu
# After:  vices et de pechie il doit oster oiseu
# Before: se dentour soy . Et meismes mõẜ
# After:  se dentour soy . Et meismes mõẜ
# Before: saint augustin cõmande q̃ chascũ
# After:  saint augustin cõmande q̃ chascũ
# Before: puis par frere Jehan de vignay
# After:  puis par frere Jehan de vignay
# Before: sant de labourer se paĩne de faire le
# After:  sant de labourer se paĩne de faire le
# Before: labour de quoy il se saura entreme
# After:  labour de quoy il se saura entreme
# Before: tre afin que il ne soit oiseus . Et
# After:  tre afin que il ne soit oiseus . Et
# Before: de ce nous donnerent les apostres
# After:  de ce nous donnerent les apostres
# Before: example . Car combien que ils
# After:  example . Car combien que ils
# Before: fussent establi de par dieu a enseig
# After:  fussent establi de par dieu a enseig
# Before: nier le peuple . quant ilz auoient
# After:  nier le peuple . quant ilz auoient
# Before: preeschie ilz se metoient a labourer
# After:  preeschie ilz se metoient a labourer
# Before: et du propre gaaing de leur labour
# After:  et du propre gaaing de leur labour
# Before: se vivoient . Et tel maniere de labo᷑
# After:  se vivoient . Et tel maniere de labo᷑
# Before: loe moult dauid le prophecte ou psal
# After:  loe moult dauid le prophecte ou psal
# Before: tier et dit . Le labour de tes mains
# After:  tier et dit . Le labour de tes mains
# Before: mengeras . tu es beneoit et il te fera
# After:  mengeras . tu es beneoit et il te fera
# Before: bien . Et vous pourrez se vo᷒ voulez
# After:  bien . Et vous pourrez se voꝰ voulez
# Before: t comme ge oi ice veuu : chei a ses
# After:  t comme ge oi ice veuu : chei a ses
# Before: piez comme mort ⁊ il mist sa destre sur
# After:  piez comme mort ⁊ il mist sa destre sur
# Before: moi & me dist . Ne aez pour. Je sui le premi
#
# After:  moi & me dist . Ne aez pour. Je sui le premi
#
# Before: ers & le darrains : & uif Je fu morz : & ore
# After:  ers & le darrains : & uif Je fu morz : & ore
# Before: uif : a tuziurs. et ge ai la clef de mort & de
# After:  uif : a tuziurs. et ge ai la clef de mort & de
# Before: enfer. Escriuez donc ceo ke uos auez veu ⁊
# After:  enfer. Escriuez donc ceo ke uos auez veu ⁊
# Before: les choses ke sunt orendret : Et ceo ke couiẽt
# After:  les choses ke sunt orendret : Et ceo ke couiẽt
# Before: uenir aprees les set esteilles ke veuu auez. a
#
# After:  uenir aprees les set esteilles ke veuu auez. a
#
# Before: ma destre sunt les set prelat de set yglises.
# After:  ma destre sunt les set prelat de set yglises.
# Before: Et les set chandelabres : sunt les set yglises.
# After:  Et les set chandelabres : sunt les set yglises.
# Before: ceo ke seint Johan quant il ot veu
# After:  ceo ke seint Johan quant il ot veu
# Before: la uisiun chei as piez au seignur : signe
# After:  la uisiun chei as piez au seignur : signe
# Before: fie ke li bon prelat qui a droite foi : se encline
# After:  fie ke li bon prelat qui a droite foi : se encline
# Before: & entent au pople deu confesser & conseiller :
# After:  & entent au pople deu confesser & conseiller :
# Before: Ceo quil est ausi comme morz : signefie ke il
# After:  Ceo quil est ausi comme morz : signefie ke il
# Before: guerpit la gloire del munde . ceo que li sires
# After:  guerpit la gloire del munde . ceo que li sires
# Before: met sa destre sur lui : signefie ke nostre sire
# After:  met sa destre sur lui : signefie ke nostre sire
# Before: done a toi p͛lat force & uigur a suffrir ꝑsecu
# After:  done a toi p̾lat force & uigur a suffrir ꝑsecu
# Before: tion. Ceo quil dist quil a clefs de mort & de
# After:  tion. Ceo quil dist quil a clefs de mort & de
# Before: enfer signifie quil le fet si hardi quil ne crẽt
# After:  enfer signifie quil le fet si hardi quil ne crẽt
# Before: ne deable ne tyrant encuntre la volẽtee deu.
# After:  ne deable ne tyrant encuntre la volẽtee deu.
# Before: pres ceo cõmanda nr̃e signur a
# After:  pres ceo cõmanda nr̃e signur a
# Before: seint johan quil escrisit a leueske de
# After:  seint johan quil escrisit a leueske de
# Before: liglise de Ephesie. ceo dist cil qui tient les
# After:  liglise de Ephesie. ceo dist cil qui tient les
# Before: set esteilles en sa destre ⁊ ua enmi les set chan
# After:  set esteilles en sa destre ⁊ ua enmi les set chan
# Before: delabres de or : je sai tes eovres & tes labours ⁊
# After:  delabres de or : je sai tes eovres & tes labours ⁊
# Before: ta pacience. & ke vos ne poez suffrir les mal
# After:  ta pacience. & ke vos ne poez suffrir les mal
# Before: veis. & cum vos avez asae & ateint de fau
# After:  veis. & cum vos avez asae & ateint de fau
# Before: sine ceus ki se funt apostles & ne sunt pas.
# After:  sine ceus ki se funt apostles & ne sunt pas.
# Before: Et ge sai les adv͛sitez ke vos avez suffert p᷑
# After:  Et ge sai les adv̾sitez ke vos avez suffert p᷑
# Before: moi. Mes une chose ia : ke uos auez guer
# After:  moi. Mes une chose ia : ke uos auez guer
# Before: pi la charitee que uos aviez au commence
# After:  pi la charitee que uos aviez au commence
# Before: ment. Pur ceo uos membre il dunt uos
# After:  ment. Pur ceo uos membre il dunt uos
# Before: estes chaez . & fetes penance des eoures : ke
# After:  estes chaez . & fetes penance des eoures : ke
# Before: uos feites auant ou ce ce nun : Ge uendroi
# After:  uos feites auant ou ce ce nun : Ge uendroi
# Before: a toi tost & mouerai tun chandelabre de sun
# After:  a toi tost & mouerai tun chandelabre de sun
# Before: liu : Si tu ne faces penance. Mes ceo auez uoᷤ
# After:  liu : Si tu ne faces penance. Mes ceo auez uoᷤᷤ
# Before: de bien ke uos auez haï les eoures as nicho
# After:  de bien ke uos auez haï les eoures as nicho
# Before: laites : ke ie haz. Ki a oreilles a oir : oie ceo
# After:  laites : ke ie haz. Ki a oreilles a oir : oie ceo
# Before: ke lespirit dist as iglises. A celui qui ueintͣ
# After:  ke lespirit dist as iglises. A celui qui ueintͣ
# Before: dorai ge a manger de larbre de uie ke est en
# After:  dorai ge a manger de larbre de uie ke est en
# Before: parais mun deu
# After:  parais mun deu
# Before: eo ke nr̃e sire commanda quil escreit al
# After:  eo ke nr̃e sire commanda quil escreit al
# Before: euesque del iglise pur les pecchiez au po
# After:  euesque del iglise pur les pecchiez au po
# Before: ple. signefie que nr̃e sire demandera des p͛laz
# After:  ple. signefie que nr̃e sire demandera des p̾laz
# Before: les ames as suggez. Par ce quil les loe de lur
# After:  les ames as suggez. Par ce quil les loe de lur
# Before: labour ⁊ de lur pacience : nus sumunt il que
# After:  labour ⁊ de lur pacience : nus sumunt il que
# Before: nus prengnum esample. Ceo quil les reprẽt
# After:  nus prengnum esample. Ceo quil les reprẽt
# Before: quil unt ꝑdu lur charitee quil auaient a
# After:  quil unt ꝑdu lur charitee quil auaient a
# Before: uant : signefie ceo ke la postle dist seint pol.
# After:  uant : signefie ceo ke la postle dist seint pol.
# Before: Si ge aie tant de foi ke ge remue les muntaig
# After:  Si ge aie tant de foi ke ge remue les muntaig
# Before: nes de liu en autre. E liure mun cors a arder
# After:  nes de liu en autre. E liure mun cors a arder
# Before: sanz ceo ke ge ne aie charitee : rien ne uaut. Ce
# After:  sanz ceo ke ge ne aie charitee : rien ne uaut. Ce
# Before: quil le manace de mouuer le candelabre sil
# After:  quil le manace de mouuer le candelabre sil
# Before: ne facent penance signefie ke sil ne samendẽt
# After:  ne facent penance signefie ke sil ne samendẽt
# Before: il lur toudra les graces quil unt. Ceo quil dit
# After:  il lur toudra les graces quil unt. Ceo quil dit
# Before: qui a oreilles a oir : signefie ceo ke nr̃e seignur
# After:  qui a oreilles a oir : signefie ceo ke nr̃e seignur
# Before: dit en leuuangile : Ceo ke ge die a un : ge di a
# After:  dit en leuuangile : Ceo ke ge die a un : ge di a
# Before: tuz Ceo quil lur promet de manger delarbre
#
# After:  tuz Ceo quil lur promet de manger delarbre
#
# Before: de uie : Signifie quil lur dorra le fruit de la
# After:  de uie : Signifie quil lur dorra le fruit de la
# Before: croiz. ceo ÷ JH̃u cͥst en la gloire sun pere. Et
# After:  croiz. ceo ÷ JH̃u cͥst en la gloire sun pere. Et
# Before: alyglise de Smirnie escriuez . ceo dit cil qui
# After:  alyglise de Smirnie escriuez . ceo dit cil qui
# Before: est li premiers & li derains commencement
# After:  est li premiers & li derains commencement
# Before: & fin : ki fu morz & uit. Je sai ur̃e tͥbulatiun
# After:  & fin : ki fu morz & uit. Je sai ur̃e tͥbulatiun
# Before: & ur̃e povertee. Mes riches estes : & li faus
# After:  & ur̃e povertee. Mes riches estes : & li faus
# Before: iuif uos ranponent . mes ne aez pour de ceo
# After:  iuif uos ranponent . mes ne aez pour de ceo
# Before: ke tu es a sofrir. & li diable fera mettre aucũs
# After:  ke tu es a sofrir. & li diable fera mettre aucũs
# Before: de uos en chartre pur uos asaer ⁊ dis iurs
# After:  de uos en chartre pur uos asaer ⁊ dis iurs
# Before: auerez tͥbulatiun. Seez feel deske a la mort
# After:  auerez tͥbulatiun. Seez feel deske a la mort
# Before: & Je uos donrai corone de uie. Qi a oreilles de
# After:  & Je uos donrai corone de uie. Qi a oreilles de
# Before: oir oie : ceo que lespirit dit as eglises ki ueĩ
# After:  oir oie : ceo que lespirit dit as eglises ki ueĩ
# Before: tra : il nauera garde de le secunde mort
# After:  tra : il nauera garde de le secunde mort
# Before: la le asaut de iuifs est signefie lasaut
# After:  la le asaut de iuifs est signefie lasaut
# Before: de auarice. ꝑ la temptatiun al deable :
# After:  de auarice. ꝑ la temptatiun al deable :
# Before: est signefie lasãut de orguil & ꝑ tͥbulatiun:
# After:  est signefie lasãut de orguil & ꝑ tͥbulatiun:
# ...
# Before: lia ꝯstitutõis sue sensus. Necesse est enĩ
# After:  lia ꝯstitutõis sue sensus. Necesse est enĩ
# Before: id sentiãt ꝑ qd̾ alia quoq sentiũt.Ne
# After:  id sentiãt ꝑ qd̾ alia quoq sentiũt.Ne
# Before: cesse e̾ enĩ eius sensũ habeãt:cui parẽt
# After:  cesse e̾ enĩ eius sensũ habeãt:cui parẽt
# Before: a quo reguntur. Nemo ñ ex uob̾ intelli
# After:  a quo reguntur. Nemo ñ ex uob̾ intelli
# Before: git ẽẽ aliquid qd̾ ĩpetus suos moueat.
# After:  git ẽẽ aliquid qd̾ ĩpetus suos moueat.
# Before: quid illd̾ ignorat. Et conatũ sibi ẽẽ scit.
# After:  quid illd̾ ignorat. Et conatũ sibi ẽẽ scit.
# Before: quis sit aut unde sit nescit. Sic infanti
# After:  quis sit aut unde sit nescit. Sic infanti
# Before: b quoq aĩalib q principal̾ sue partis
# After:  b quoq aĩalib q principal̾ sue partis
# Before: sensus e̾.ñ satis dilutidus nec exp̾ssus
# After:  sensus e̾.ñ satis dilutidus nec exp̾ssus
# Before: Dicitis ĩquis õe aĩal primũ ꝯstitutõm
# After:  Dicitis ĩquis õe aĩal primũ ꝯstitutõm
# Before: sue ꝯciliari.hoĩs autẽ ꝯstitutõem ratõ
# After:  sue ꝯciliari.hoĩs autẽ ꝯstitutõem ratõ
# Before: nalẽ ẽẽ. ⁊ ideo ꝯciliari hoĩem sibi ñ tan
# After:  nalẽ ẽẽ. ⁊ ideo ꝯciliari hoĩem sibi ñ tan
# Before: ꝙͣ aĩali. s tamꝙͣ ratõnali. Ea enĩ carte
# After:  ꝙͣ aĩali. s tamꝙͣ ratõnali. Ea enĩ carte
# Before: sibi garꝰ est homo: qua hõ e̾.Quõ ergo in
# After:  sibi garꝰ est homo: qua hõ e̾.Quõ ergo in
# Before: fans ꝯciliari ꝯstitutioni rõnali potest.
# After:  fans ꝯciliari ꝯstitutioni rõnali potest.
# Before: cũ ratõnalis nũdũ sit Vnicuiq eta
# After:  cũ ratõnalis nũdũ sit Vnicuiq eta
# Before: ti sua ꝯstiutio e̾. Alia infanti. Alia pu̾o.
# After:  ti sua ꝯstiutio e̾. Alia infanti. Alia pu̾o.
# Before: epͣ vi ͯ ͯ
# After:  epͣ vi
# Before: alia seni. Os̃ ei ꝯstitutoĩ ꝯciliãtur. ĩ qͣ sũt
# After:  alia seni. Os̃ ei ꝯstitutoĩ ꝯciliãtur. ĩ qͣ sũt
# Before: Infans sine dentib e̾. huic ꝯstitutõi ꝯci
# After:  Infans sine dentib e̾. huic ꝯstitutõi ꝯci
# Before: liatur sue. Ei nati sũt dentes: huic ꝯsti
# After:  liatur sue. Ei nati sũt dentes: huic ꝯsti
# Before: tutõi ꝯciliatur.Nã ⁊ illa h̾ba q̃ in sege
# After:  tutõi ꝯciliatur.Nã ⁊ illa h̾ba q̃ in sege
# Before: tẽ frugẽ q uẽtura e̾.aliã ꝯstitũtõnem
# After:  tẽ frugẽ q uẽtura e̾.aliã ꝯstitũtõnem
# Before: ht̃ tenera: ⁊ uix eminẽs sulco. aliã con
# After:  ht̃ tenera: ⁊ uix eminẽs sulco. aliã con
# Before: ualuit.⁊ molli quidẽ culmo quo ferat o
# After:  ualuit.⁊ molli quidẽ culmo quo ferat o
# Before: nus suũ ꝯstitit.aliã cũ flauescit.⁊ ad
# After:  nus suũ ꝯstitit.aliã cũ flauescit.⁊ ad
# Before: areã spectat ⁊ spica eiꝰ ĩduruit. Jn ꝙͣcũq
# After:  areã spectat ⁊ spica eiꝰ ĩduruit. Jn ꝙͣcũq
# Before: ꝯstitutõem uenit. eã tuetur.in eã ꝯponit᷑
# After:  ꝯstitutõem uenit. eã tuetur.in eã ꝯponit᷑
# Before: Alia e̾ etas infãtis. pueri. adolescẽtis. senis
# After:  Alia e̾ etas infãtis. pueri. adolescẽtis. senis
# Before: ego tñ idẽ sũ qui ⁊ infãs fui: ⁊ puer. ⁊ ad
# After:  ego tñ idẽ sũ qui ⁊ infãs fui: ⁊ puer. ⁊ ad
# Before: olescens. Sic ꝙͣuis alia atq alia cuiq cõ
# After:  olescens. Sic ꝙͣuis alia atq alia cuiq cõ
# Before: stitutõ sit. ꝯciliatõ ꝯstitutõis sue eadẽ e̾.
# After:  stitutõ sit. ꝯciliatõ ꝯstitutõis sue eadẽ e̾.
# Before: Ñ enĩ pueꝵ michi aut iuuenẽ au senẽ
# After:  Ñ enĩ pueꝵ michi aut iuuenẽ au senẽ
# Before: s me natura ꝯmẽdat.Ergo ĩfans ꝯsti
# After:  s me natura ꝯmẽdat.Ergo ĩfans ꝯsti
# Before: tutõi sue ꝯciliatur: qͣ tũc infãti e̾. ñ que
# After:  tutõi sue ꝯciliatur: qͣ tũc infãti e̾. ñ que
# Before: futura iuueni e̾. Neq enĩ si aliꝙͥ illi ma
# After:  futura iuueni e̾. Neq enĩ si aliꝙͥ illi ma
# Before: ius in qd̾ tnͣseat restat: ĩ hoc quoꝙ in
# After:  ius in qd̾ tnͣseat restat: ĩ hoc quoꝙ in
# Before: quo nascitur scd̾m naturã e̾. Prmũ sibi
# After:  quo nascitur scd̾m naturã e̾. Prmũ sibi
# Before: ip̃i ꝯciliatur aĩal. Debet enĩ aliquid esse
# After:  ip̃i ꝯciliatur aĩal. Debet enĩ aliquid esse
# Before: ad alia referãtur. uoluptatẽ peto. Cui:
# After:  ad alia referãtur. uoluptatẽ peto. Cui:
# Before: michi. Ergo mei curã ago dolorẽ refugi
# After:  michi. Ergo mei curã ago dolorẽ refugi
# Before: o. ꝓ quo: ꝑ me. Ergo mei curã ago.Si
# After:  o. ꝓ quo: ꝑ me. Ergo mei curã ago.Si
# Before: oĩa ꝓpt̾ curã mei facio: añ oĩa mei est
# After:  oĩa ꝓpt̾ curã mei facio: añ oĩa mei est
# Before: cura. hec aĩalib inest cũctis. Nec inserit᷑
# After:  cura. hec aĩalib inest cũctis. Nec inserit᷑
# Before: s innascitur ꝓducit fetus suos natu
# After:  s innascitur ꝓducit fetus suos natu
# Before: ra: ñ abicit. Et q tutela c̾tissima ex ꝓ
# After:  ra: ñ abicit. Et q tutela c̾tissima ex ꝓ
# Before: ximo e̾:sibi quisq ꝯmissus e: Itaq ut
# After:  ximo e̾:sibi quisq ꝯmissus e: Itaq ut
# Before: in priorib epli̾s dixi. ten̾a quoq aĩalia
# After:  in priorib epli̾s dixi. ten̾a quoq aĩalia
# Before: ⁊ mat̾no utero ul̾ quoquomͦ effusa quid
# After:  ⁊ mat̾no utero ul̾ quoquomͦ effusa quid
# Before: sit ĩ festũ ipĩs ꝓtinꝰ norũt ⁊ mortifera de
# After:  sit ĩ festũ ipĩs ꝓtinꝰ norũt ⁊ mortifera de
# Before: uitãt umbrã quoq tnͣsuolãtiũ reformi
# After:  uitãt umbrã quoq tnͣsuolãtiũ reformi
# Before: dãt obnoxia auib rapto uiuentib Nul
# After:  dãt obnoxia auib rapto uiuentib Nul
# Before: lũ aĩal ad uitã ꝓdit. sine metu mortis
# After:  lũ aĩal ad uitã ꝓdit. sine metu mortis
# Before: XIII
# After:  XIII
# Before: Ꝙ̃ ad mod̾
# After:  Ꝙ̃ ad mod̾
# Before: tege.in hora mortis suscipe
# After:  tege.in hora mortis suscipe
# Before: Gloria tibi dñe.qui natus
# After:  Gloria tibi dñe.qui natus
# Before: es de virgine. cum patre et
# After:  es de virgine. cum patre et
# Before: sancto spiritu. in sempiter
# After:  sancto spiritu. in sempiter
# Before: na secula .Am̃ a̾ maria v̾go
# After:  na secula .Am̃ a̾ maria v̾go
# Before: D dñm cum tribu p̃s
# After:  D dñm cum tribu p̃s
# Before: larer clamaui: et exau
# After:  larer clamaui: et exau
# Before: diuit me Dñe libera aĩam
# After:  diuit me Dñe libera aĩam
# Before: meam a labiis iniquis :t̃ a
# After:  meam a labiis iniquis :t̃ a
# Before: lingua dolosa Quid detur
# After:  lingua dolosa Quid detur
# Before: tibi aut quid apponatur
# After:  tibi aut quid apponatur
# Before: tibi :ad linguam dolosam
# After:  tibi :ad linguam dolosam
# Before: Sagitte potentis acute:
# After:  Sagitte potentis acute:
# Before: cum carbonib desolatorijs
# After:  cum carbonib desolatorijs
# Before: pr̃i ⁊ filio :et spũi scõ Sicut e
# After:  pr̃i ⁊ filio :et spũi scõ Sicut e
# Before: rat in p̾ncipio et nũc et sẽꝑ.
# After:  rat in p̾ncipio et nũc et sẽꝑ.
# Before: et in scl̾a scl̾oꝵ amen Dñs
# After:  et in scl̾a scl̾oꝵ amen Dñs
# Before: tecũ .Aue maͣ g. p. d. tecũ ỹnꝰ
# After:  tecũ .Aue maͣ g. p. d. tecũ ynꝰ
# Before: Uem terra pontus e
# After:  Uem terra pontus e
# Before: thera .colunt adorant
# After:  thera .colunt adorant
# Before: predicant .trinam regentẽ
# After:  predicant .trinam regentẽ
# Before: machinam .claustrũ marie
# After:  machinam .claustrũ marie
# Before: baiulat Cui luna sol et oĩa
# After:  baiulat Cui luna sol et oĩa
# Before: deseruiunt ꝑ tempora .ꝑfusa
# After:  deseruiunt ꝑ tempora .ꝑfusa
# Before: celi gratia gestant puelle
# After:  celi gratia gestant puelle
# Before: viscera Beata m̃r mun̾e
# After:  viscera Beata m̃r mun̾e
# Before: cuius suꝑnus artifex mũ
# After:  cuius suꝑnus artifex mũ
# Before: dum pugillo continens .
# After:  dum pugillo continens .
# Before: lem aulam beate marie vir
# After:  lem aulam beate marie vir
# Before: ginis .in qua habitares elig̾e
# After:  ginis .in qua habitares elig̾e
# Before: dignatus es :da quesumus.
# After:  dignatus es :da quesumus.
# Before: ut sua nos defensione mu
# After:  ut sua nos defensione mu
# Before: nitos iocundos .nos faciat
# After:  nitos iocundos .nos faciat
# Before: interesse sue cõmemorationi
# After:  interesse sue cõmemorationi
# Before: Qui viuis et regnas deus :
# After:  Qui viuis et regnas deus :
# Before: ꝑ omnia secula seculorum .
# After:  ꝑ omnia secula seculorum .
# Before: Amen añ Sancti dei omnes
# After:  Amen añ Sancti dei omnes
# Before: intercedere dignemini pro
# After:  intercedere dignemini pro
# Before: nostra oĩmq salute v̾ leta
# After:  nostra oĩmq salute v̾ leta
# Before: mini in domino et exultate
# After:  mini in domino et exultate
# Before: iusti .Et gloriamini omnes
# After:  iusti .Et gloriamini omnes
# Before: recti corde .Oremus Oratio
# After:  recti corde .Oremus Oratio
# Before: Quẽadmod̾ ĩquit editũ aĩal intell̾im hr̃e
# After:  Quẽadmod̾ ĩquit editũ aĩal intell̾im hr̃e
# Before: aut salutaris aut mortise̾ rei potest. Primũ
# After:  aut salutaris aut mortise̾ rei potest. Primũ
# Before: q̃ritur an intelligat. aut ꝙ̃admod̾ ĩtelli
# After:  q̃ritur an intelligat. aut ꝙ̃admod̾ ĩtelli
# Before: gat ẽẽ aut̃ intellc̾m illis ex eo apparet.qd̾
# After:  gat ẽẽ aut̃ intellc̾m illis ex eo apparet.qd̾
# Before: nich̾ ãplius si intellex̾unt faciẽt. Quid
# After:  nich̾ ãplius si intellex̾unt faciẽt. Quid
# Before: e̾ qͣre pauonẽ qͣre anserẽ gallina refugi
# After:  e̾ qͣre pauonẽ qͣre anserẽ gallina refugi
# Before: at. At tanto minor e̾: ⁊ne notã quidẽ sibi
# After:  at. At tanto minor e̾: ⁊ne notã quidẽ sibi
# Before: accipit rẽ. Qͣre pulli felẽ timeãt canẽ ñ
# After:  accipit rẽ. Qͣre pulli felẽ timeãt canẽ ñ
# Before: timeãt: Apꝑet ill̾ ñ ẽẽ nocituri sciãm. ñ
# After:  timeãt: Apꝑet ill̾ ñ ẽẽ nocituri sciãm. ñ
# Before: exꝑimẽto collectã. Nã añꝙͣ possĩt exꝑiri
# After:  exꝑimẽto collectã. Nã añꝙͣ possĩt exꝑiri
# Before: cauẽt. Deinde ne hoc casu existimes fieri
# After:  cauẽt. Deinde ne hoc casu existimes fieri
# Before: nec metuũt alia ꝙͣ debẽt. nec unꝙͣ obliui
# After:  nec metuũt alia ꝙͣ debẽt. nec unꝙͣ obliui
# Before: sꝯtur huiꝰ tutele ⁊ diligẽtie. Equal̾ e̾ ill̾
# After:  sꝯtur huiꝰ tutele ⁊ diligẽtie. Equal̾ e̾ ill̾
# Before: a ꝑnitioso fuga. Prete̾a ñ fiũt timidio
# After:  a ꝑnitioso fuga. Prete̾a ñ fiũt timidio
# Before: ra uiuẽdo.ex quo quidẽ apparet ñ usu
# After:  ra uiuẽdo.ex quo quidẽ apparet ñ usu
# Before: illa m hoe ꝑuenire s naturali amore sa
# After:  illa m hoe ꝑuenire s naturali amore sa
# Before: luis sue. Et tardũ e̾ ⁊ uariũ qd̾ usus do
# After:  luis sue. Et tardũ e̾ ⁊ uariũ qd̾ usus do
# Before: cet. quicꝙͥ natura t̃dit ⁊ eqͣle oĩb e̾: ⁊ sta
# After:  cet. quicꝙͥ natura t̃dit ⁊ eqͣle oĩb e̾: ⁊ sta
# Before: tim. Si tm̃ exigis dicã quõ õe aĩal ꝑni
# After:  tim. Si tm̃ exigis dicã quõ õe aĩal ꝑni
# Before: tiosa intellig̾e conatur.Sentit se carne
# After:  tiosa intellig̾e conatur.Sentit se carne
# Before: ꝯstare. Sentit itaq quid sit quo secari
# After:  ꝯstare. Sentit itaq quid sit quo secari
# Before: caro quo uriquo obt̾i possit que sint
# After:  caro quo uriquo obt̾i possit que sint
# Before: aĩalia armata ad nocẽdũ. horũ specien
# After:  aĩalia armata ad nocẽdũ. horũ specien
# Before: trahit ĩimicã ⁊ hostilẽ. Int̾ se ista ꝯiun
# After:  trahit ĩimicã ⁊ hostilẽ. Int̾ se ista ꝯiun
# Before: cta sũt. sunt̾ enĩ ꝯciliãtur saluti sue.q̃q
# After:  cta sũt. sunt̾ enĩ ꝯciliãtur saluti sue.q̃q
# Before: iuuãt illa petit lesuꝵ forimidat. natu
# After:  iuuãt illa petit lesuꝵ forimidat. natu
# Before: rales a ꝯtrarijs: asꝑnatões sũt. Sine
# After:  rales a ꝯtrarijs: asꝑnatões sũt. Sine
# Before: ulla cogitatõe eᷤ q̃ hoc dicit. sine ꝯsilio fit
# After:  ulla cogitatõe eᷤᷤ q̃ hoc dicit. sine ꝯsilio fit
# Before: quicꝙͥ. natura p̾cipit. Ñ uides qnͣta sit
# After:  quicꝙͥ. natura p̾cipit. Ñ uides qnͣta sit
# Before: subtilitas apib ad fingẽda domiciliaa.
# After:  subtilitas apib ad fingẽda domiciliaa.
# Before: qnͣta diuidus laboris obeũdi q ꝯcordia.
# After:  qnͣta diuidus laboris obeũdi q ꝯcordia.
# Before: Ñ uides ꝙͣ nlli̾ mortaliũ mutabil̾ sit
# After:  Ñ uides ꝙͣ nlli̾ mortaliũ mutabil̾ sit
# Before: illa aranee textura.qnͣti oꝑis sit fila dis
# After:  illa aranee textura.qnͣti oꝑis sit fila dis
# Before: pon̾e.Alia in rectũ ĩnissa firmam̃ti lo
# After:  pon̾e.Alia in rectũ ĩnissa firmam̃ti lo
# Before: ci. Alia ĩ orbẽ currẽtia eo dentiora quo
# After:  ci. Alia ĩ orbẽ currẽtia eo dentiora quo
# Before: vi ͯ ͯ
# After:  vi
# Before: minora quib aĩalia ĩ quoꝵ p̾cipitum
# After:  minora quib aĩalia ĩ quoꝵ p̾cipitum
# Before: illa tendũtur. uelut retib ĩplicata tene
# After:  illa tendũtur. uelut retib ĩplicata tene
# Before: antur. Nascinur ars ista ñ discitur. Itaq
# After:  antur. Nascinur ars ista ñ discitur. Itaq
# Before: nllm̾ e̾ aĩal alt̾o doctiꝰ uideb̾ araneaꝵ
# After:  nllm̾ e̾ aĩal alt̾o doctiꝰ uideb̾ araneaꝵ
# Before: pares telas. par ĩ fauis anglo̾ꝵ oĩm fo
# After:  pares telas. par ĩ fauis anglo̾ꝵ oĩm fo
# Before: ram̃e.Incertũ e̾ ⁊ ĩeqͣbile quiꝙͥ ars tra
# After:  ram̃e.Incertũ e̾ ⁊ ĩeqͣbile quiꝙͥ ars tra
# Before: dit. exequo uenit qo natura distribuit.
# After:  dit. exequo uenit qo natura distribuit.
# Before: hec nich̾ magis ꝙͣ tutelã sui ⁊ eiꝰ ꝑitiam
# After:  hec nich̾ magis ꝙͣ tutelã sui ⁊ eiꝰ ꝑitiam
# Before: tradidit. Ideoq etiã siml̾ incipiũt ⁊ disce̾
# After:  tradidit. Ideoq etiã siml̾ incipiũt ⁊ disce̾
# Before: ⁊ uiu̾e. nec e̾ miꝵ cũ eo nasci illa. sine quo
# After:  ⁊ uiu̾e. nec e̾ miꝵ cũ eo nasci illa. sine quo
# Before: frustra nasc̾entur. Primũ hoc ĩstrum̃tũ
# After:  frustra nasc̾entur. Primũ hoc ĩstrum̃tũ
# Before: illa natura ꝯtulit ad ꝑmanendũ ĩ ꝯcili
# After:  illa natura ꝯtulit ad ꝑmanendũ ĩ ꝯcili
# Before: atõem ⁊ caritatẽ suj. Ñ pot̾ant salua eẽ:
# After:  atõem ⁊ caritatẽ suj. Ñ pot̾ant salua eẽ:
# Before: nisi uellẽt. Nec ñ hoc ꝓ futuꝵ erat. Sine
# After:  nisi uellẽt. Nec ñ hoc ꝓ futuꝵ erat. Sine
# Before: hoc nlla̾ res ꝓfuiss. S in nlla̾ dep̾hendes
# After:  hoc nlla̾ res ꝓfuiss. S in nlla̾ dep̾hendes
# Before: uilitate sui neglĩam. Tacitis quoq ⁊ bru
# After:  uilitate sui neglĩam. Tacitis quoq ⁊ bru
# Before: tis quãꝙ̃ in cet̾a torpeant aduinẽdum
# After:  tis quãꝙ̃ in cet̾a torpeant aduinẽdum
# Before: solertia e̾. Videbis q̃ alijs ĩutilia sũt:sibi
# After:  solertia e̾. Videbis q̃ alijs ĩutilia sũt:sibi
# Before: ip̃i non deesse. Vale.
# After:  ip̃i non deesse. Vale.
# Before: .xxxͣij.
# After:  .xxxͣij.
# Before: etrim̃tũ iã dies sensit resiliuit ali
# After:  etrim̃tũ iã dies sensit resiliuit ali
# Before: qnͣtulũ ita tm̃ ut lib̾ale adhucspa
# After:  qnͣtulũ ita tm̃ ut lib̾ale adhucspa
# Before: ciũ sit.si quis cũ ip̃o ut ita dicã die sur
# After:  ciũ sit.si quis cũ ip̃o ut ita dicã die sur
# Before: gat officiosior meliorq siquis illũ expe
# After:  gat officiosior meliorq siquis illũ expe
# Before: ctat.⁊ lucẽ primã exuit. Turpis qui alto
# After:  ctat.⁊ lucẽ primã exuit. Turpis qui alto
# Before: sole semisõpniꝰ iacet cuius uigilia medi
# After:  sole semisõpniꝰ iacet cuius uigilia medi
# Before: o die ĩcepit. ⁊adhc̃ ml̾tis hoc añ lucanũ
# After:  o die ĩcepit. ⁊adhc̃ ml̾tis hoc añ lucanũ
# Before: e̾. Sũt qui officia lucis noctis q ꝑu̾terint
# After:  e̾. Sũt qui officia lucis noctis q ꝑu̾terint
# Before: nec ante deducos oclo̾s. hest̾na graues cra
# After:  nec ante deducos oclo̾s. hest̾na graues cra
# Before: pula: ꝙͣ apꝑere nox cepit. Qual̾ illoꝵ ꝯdi
# After:  pula: ꝙͣ apꝑere nox cepit. Qual̾ illoꝵ ꝯdi
# Before: tõ dicitur:quos natura ut ait uirgilius
# After:  tõ dicitur:quos natura ut ait uirgilius
# Before: sedib nr̃is subditos eꝯtrario posuit hos
# After:  sedib nr̃is subditos eꝯtrario posuit hos
# Before: q ubi primꝰ equis oriẽs afflauit anelis:
# After:  q ubi primꝰ equis oriẽs afflauit anelis:
# Before: ill̾ sera rubens accendit lumina uesper:
# After:  ill̾ sera rubens accendit lumina uesper:
# Before: Tal̾ hoꝵ ꝯtͣria oĩb ñ regio s uita e̾. Sũt
# After:  Tal̾ hoꝵ ꝯtͣria oĩb ñ regio s uita e̾. Sũt
# Before: quidã ĩ eadẽ urbe antipodes. qui ut mareꝰ
# After:  quidã ĩ eadẽ urbe antipodes. qui ut mareꝰ
# Before: Eus in
# After:  Eus in
# Before: adiutori
# After:  adiutori
# Before: um meũ
# After:  um meũ
# Before: intende.
# After:  intende.
# Before: Domine
# After:  Domine
# Before: ad adiu
# After:  ad adiu
# Before: uandũ
# After:  uandũ
# Before: me festina Gl̾a pr̃i ⁊ ỹnꝰ
# After:  me festina Gl̾a pr̃i ⁊ ynꝰ
# Before: Emento salutis auc
# After:  Emento salutis auc
# Before: tor.ꝙ nostri quondã
# After:  tor.ꝙ nostri quondã
# Before: corporis. exillibata virgine.
# After:  corporis. exillibata virgine.
# Before: nascendo formã sumpseris
# After:  nascendo formã sumpseris
# Before: Maria mater gracie mat̾
# After:  Maria mater gracie mat̾
# Before: miscdi̾e .tu nos ab hoste ꝓ
# After:  miscdi̾e .tu nos ab hoste ꝓ

# %%
print(extracted_data)

# %%
import os
import json
import random

def split_data(json_data, train_percentage=0.85):
    # Step 1: Identify unique groups
    unique_groups = set(key.split('_')[0] for key in json_data.keys())

    # Step 2 and 3: Randomly split each group
    for group in unique_groups:
        group_keys = [key for key in json_data.keys() if key.startswith(group)]
        group_size = len(group_keys)
        train_size = int(group_size * train_percentage)

        # Randomly shuffle the keys to ensure a random split
        random.shuffle(group_keys)

        # Update "split" values for training and validation
        for key in group_keys[:train_size]:
            json_data[key]["split"] = "train"
        for key in group_keys[train_size:]:
            json_data[key]["split"] = "val"

    return json_data

def process_directory(directory_path):
    for root, dirs, files in os.walk(directory_path):
        for file_name in files:
            if file_name.endswith('.json'):
                file_path = os.path.join(root, file_name)
                print(f"Processing file: {file_path}")

                try:
                    # Load JSON data
                    with open(file_path, 'r', encoding='utf-8') as file:
                        json_data = json.load(file)

                    # Apply the split_data function
                    json_data = split_data(json_data)

                    # Save the updated JSON data for each file
                    with open(file_path, 'w', encoding='utf-8') as file:
                        json.dump(json_data, file, indent=2)

                except Exception as e:
                    print(f"Error processing file {file_path}: {e}")

# Replace 'your_directory_path' with the actual path to your directory
process_directory('./')
# Out:
# Processing file: ./cremma/annotation.json
# Processing file: ./textualis_formata/annotation.json
# Processing file: ./south_north_textualis/annotation.json
